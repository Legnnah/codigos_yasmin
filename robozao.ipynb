# %%
# estou importando e ele de aut
#import pyautogui as aut

# pressiono a tecla de atalho win + r
#aut.hotkey("win","r")
# escrever notepad
#aut.write("notepad", interval=0.7)
# espera 1 segundo 
#aut.sleep(1)
# aperta o enter   
#aut.press("Enter")

# código
#aut.hotkey("win","r")
#aut.write("https://github.com/Legnnah", interval=0.1)
#aut.press("Enter")

# %% [markdown]
# ### Pegando a posição do Mouse

# %%
# informações do mouse
aut.mouseInfo()
